# %%
#upload (menggunakan sample data)

import pandas as pd
import nltk

data = pd.read_csv("testupload.csv",encoding='latin1')
print(data)
# Out:
#                                                tweets  \
# 0   Di tengah kota di kota besar di eropa /amerika...
# 1   "jare meh tuku mobil nyol, mobil opo?"\r"MOBIL...
# 2         Hujan masih air\rNek hujan linggis yo gawat
# 3   Hehehe, nggak tahu liriknya pokoknya\rDenpasar...
# 4   Pliss jangan bego karena cinta !\rLu aja ga bi...
# 5                              MAU NONTON GAK SEEEH?!
# 6             Filmku menang di JAFF! Mau nonton gak?!
# 7           23.31\rjatikencana hujan mengandung angin
# 8                  Membahas smua \rMaaf TLku no tipu2
# 9            Kasih yang terbaik, buktikan dilapangan.
# 10  Mantap kali rasanya liat taruna AKPOL lagi pes...
# 11  aku kudanan \r Nangdi??\r Nang njero omah\rSeh...
# 12                                 di tulis pegon aja
# 13  Lagi ngumpulin orang orang yang malem minggu c...
# 14  Yg dikamar ngapain si ribet mau keluar? Orang ...
# 15  gak tau salah saya apa,tiba" di block,di kick ...
# ...

# %%
#mengecilkan semua huruf

corpus = data.astype(str).apply(lambda x: x.str.lower())
corpus
# Out:
#                                                tweets  \
# 0   di tengah kota di kota besar di eropa /amerika...
# 1   "jare meh tuku mobil nyol, mobil opo?"\r"mobil...
# 2         hujan masih air\rnek hujan linggis yo gawat
# 3   hehehe, nggak tahu liriknya pokoknya\rdenpasar...
# 4   pliss jangan bego karena cinta !\rlu aja ga bi...
# 5                              mau nonton gak seeeh?!
# 6             filmku menang di jaff! mau nonton gak?!
# 7           23.31\rjatikencana hujan mengandung angin
# 8                  membahas smua \rmaaf tlku no tipu2
# 9            kasih yang terbaik, buktikan dilapangan.
# 10  mantap kali rasanya liat taruna akpol lagi pes...
# 11  aku kudanan \r nangdi??\r nang njero omah\rseh...
# 12                                 di tulis pegon aja
# 13  lagi ngumpulin orang orang yang malem minggu c...
# 14  yg dikamar ngapain si ribet mau keluar? orang ...
# 15  gak tau salah saya apa,tiba" di block,di kick ...
# ...

# %%
#mau menghilangkan \r, simbol dan angka (belum bisa)

# %%
#normalization

lookup_dict = {"blm":"belum", "bs":"bisa", "tmn":"teman", "jd":"jadi", "dearrr":"dear", "yg":"yang", "tks":"terima kasih",
               "sdh":"sudah", "brp":"berapa", "org":"orang", "lbh":"lebih", "spy":"supaya", "tp":"tapi", "td":"tadi",
               "kl":"kalau", "g":"nggak", "hmpr":"hampir", "bwt":"buat", "udh":"sudah", "utk":"untuk", "ps":"pasar",
               "jgn":"jangan", "jl":"jalan", "gt":"gitu", "bgt":"banget", "woww":"wow", "aminn": "aamiin", "aamin":"aamiin",
               "amin":"aamiin", "met":"selamat", "netaas": "menetas", "keberpa": "keberapa", "eeeehhhh":"eh", "kata2nyaaa":"kata-katanya",
               "halloo":"halo", "kaka":"kakak", "ka":"kak", "dah":"sudah", "daah":"sudah", "aaaaahhhh":"ah", "yaa":"ya", "yaaa":"ya",
               "smga":"semoga", "slalu":"selalu"}

#mau pakai slang.dic yang datanya sudah saya ambil dari github kata alay, gimana ya caranya?
